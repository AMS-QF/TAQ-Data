# %% [markdown]
# ### Example Notebook for Pipelines
#
# Includes cleaning, datapreprocessing, feature engineering, and model training

# %%
import sklearn
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import collections
from itertools import chain
import matplotlib.pyplot as plt
from pathlib import Path

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn import set_config
from sklearn.compose import make_column_selector, make_column_transformer
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Data
# ### 1.1 Load/Import Data

# %%
TRADE_PATH =""
QUOTE_PATH = ""

# %%
trades = pd.read_csv(Path(TRADE_PATH))
quotes = pd.read_csv(Path(QUOTE_PATH))

# %%
trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280948 entries, 0 to 280947
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Unnamed: 0.1                            280948 non-null  int64
#  1   Unnamed: 0                              280948 non-null  int64
#  2   Time                                    280948 non-null  object
#  3   Date                                    280948 non-null  object
#  4   Exchange                                280948 non-null  object
#  5   Symbol                                  280948 non-null  object
#  6   Trade_Volume                            280948 non-null  int64
#  7   Trade_Price                             280948 non-null  float64
#  8   Sale_Condition                          280948 non-null  object
#  9   Source_of_Trade                         280948 non-null  object
#  10  Trade_Stop_Stock_Indicator              0 non-null       float64
#  11  Trade_Correction_Indicator              280948 non-null  int64
#  12  Sequence_Number                         280948 non-null  int64
#  13  Trade_Id                                280948 non-null  int64
#  14  Trade_Reporting_Facility                280948 non-null  object
#  15  Participant_Timestamp                   280948 non-null  int64
#  16  Trade_Reporting_Facility_TRF_Timestamp  110001 non-null  float64
#  17  Trade_Through_Exempt_Indicator          280948 non-null  int64
# dtypes: float64(3), int64(8), object(7)
# memory usage: 38.6+ MB

# %% [markdown]
# Note: All column information of trades and quotes data and valid entries for each column can be found at https://www.nyse.com/publicdocs/nyse/data/Daily_TAQ_Client_Spec_v3.0.pdf

# %%
trades.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                        Time        Date Exchange  \
# 0             0           0  2020-01-03 04:00:00.063086  2020-01-03        P
# 1             1           1  2020-01-03 04:00:00.267793  2020-01-03        P
# 2             2           2  2020-01-03 04:00:00.566842  2020-01-03        Q
# 3             3           3  2020-01-03 04:00:00.566988  2020-01-03        Q
# 4             4           4  2020-01-03 04:00:02.323113  2020-01-03        Q
#
#   Symbol  Trade_Volume  Trade_Price Sale_Condition Source_of_Trade  \
# 0   AAPL          1602       297.35           @ T                N
# 1   AAPL             1       297.12           @ TI               N
# 2   AAPL             3       297.20           @FTI               N
# 3   AAPL             1       297.20           @FTI               N
# 4   AAPL            74       297.20           @FTI               N
#
#    Trade_Stop_Stock_Indicator  Trade_Correction_Indicator  Sequence_Number  \
# 0                         NaN                           0             1196
# 1                         NaN                           0             1200
# 2                         NaN                           0             1205
# 3                         NaN                           0             1206
# 4                         NaN                           0             1210
#
#    Trade_Id Trade_Reporting_Facility  Participant_Timestamp  \
# 0         1                                  40000062702080
# 1         2                                  40000267410944
# 2         1                                  40000566817254
# 3         2                                  40000566971025
# 4         3                                  40002323090401
#
#    Trade_Reporting_Facility_TRF_Timestamp  Trade_Through_Exempt_Indicator
# 0                                     NaN                               1
# 1                                     NaN                               0
# 2                                     NaN                               1
# 3                                     NaN                               1
# 4                                     NaN                               1

# %%
quotes.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                        Time Exchange Symbol  \
# 0             0           0  2020-01-03 04:00:00.011488        Q   AAPL
# 1             1           1  2020-01-03 04:00:00.064223        P   AAPL
# 2             2           2  2020-01-03 04:00:00.064233        P   AAPL
# 3             3           3  2020-01-03 04:00:00.064235        P   AAPL
# 4             4           4  2020-01-03 04:00:00.064235        P   AAPL
#
#    Bid_Price  Bid_Size  Offer_Price  Offer_Size Quote_Condition  \
# 0       0.00       0.0       299.91         1.0               R
# 1     278.00       7.0         0.00         0.0               R
# 2     278.00      14.0         0.00         0.0               R
# 3     278.00      14.0       297.55         1.0               R
# 4     295.58       1.0       297.55         1.0               R
#
#    Sequence_Number  National_BBO_Indicator  FINRA_BBO_Indicator  \
# 0             1198                       2                  NaN
# 1             2218                       2                  NaN
# 2             2219                       2                  NaN
# 3             2220                       4                  NaN
# 4             2221                       4                  NaN
#
#    FINRA_ADF_MPID_Indicator  Quote_Cancel_Correction Source_Of_Quote  \
# 0                       NaN                      NaN               N
# 1                       NaN                      NaN               N
# 2                       NaN                      NaN               N
# 3                       NaN                      NaN               N
# 4                       NaN                      NaN               N
#
#   Retail_Interest_Indicator  Short_Sale_Restriction_Indicator  \
# 0                       NaN                                 0
# 1                       NaN                                 0
# 2                       NaN                                 0
# 3                       NaN                                 0
# 4                       NaN                                 0
#
#    LULD_BBO_Indicator SIP_Generated_Message_Identifier NBBO_LULD_Indicator  \
# 0                 NaN                              NaN                 NaN
# 1                 NaN                              NaN                 NaN
# 2                 NaN                              NaN                 NaN
# 3                 NaN                              NaN                 NaN
# 4                 NaN                              NaN                 NaN
#
#    Participant_Timestamp  FINRA_ADF_Timestamp  \
# 0         40000011469003                  NaN
# 1         40000063838720                  NaN
# 2         40000063840512                  NaN
# 3         40000063845120                  NaN
# 4         40000063845888                  NaN
#
#    FINRA_ADF_Market_Participant_Quote_Indicator Security_Status_Indicator  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#          Date  YearMonth
# 0  2020-01-03     202001
# 1  2020-01-03     202001
# 2  2020-01-03     202001
# 3  2020-01-03     202001
# 4  2020-01-03     202001

# %% [markdown]
# ### 1.2 Data Visualization & Preliminary Analysis

# %% [markdown]
# ### 1.3 Data Cleaning

# %% [markdown]
# Before we move towards feature generation and building machine learning models, we have to clean the dataset. The necessary steps to clean the trades and quotes data include:
# 1. Get rid of unnecessary columns.
# 2. Get rid of the invalid trades and quotes.
# 3. Event reconstruction.
# 4. Only keep the natural best bid/offer or last MQU.
# 5. Assign Last Active Quote and assign to the corresponding trade.

# %% [markdown]
# ## SCIKIT-LEARN DESIGN
#
# https://arxiv.org/pdf/1309.0238.pdf
#
# Scikit-Learn’s API is remarkably well designed. These are the main design components of Scikit-Learn.
#
# All objects share a consistent and simple interface:
#
# ### Estimators
#
# Any object that can estimate some parameters based on a dataset is called an estimator (e.g., a SimpleImputer is an estimator). The estimation itself is performed by the fit() method, and it takes a dataset as a parameter, or two for supervised learning algorithms—the second dataset contains the labels. Any other parameter needed to guide the estimation process is considered a hyperparameter (such as a SimpleImputer’s strategy), and it must be set as an instance variable (generally via a constructor parameter).
#
# ### Transformers
#
# Some estimators (such as a SimpleImputer) can also transform a dataset; these are called transformers. Once again, the API is simple: the transformation is performed by the transform() method with the dataset to transform as a parameter. It returns the transformed dataset. This transformation generally relies on the learned parameters, as is the case for a SimpleImputer. All transformers also have a convenience method called fit_transform(), which is equivalent to calling fit() and then transform() (but sometimes fit_transform() is optimized and runs much faster).
#
#
# ### Predictors
#
# Finally, some estimators, given a dataset, are capable of making predictions; they are called predictors. For example, the LinearRegression model in the previous chapter was a predictor: given a country’s GDP per capita, it predicted life satisfaction. A predictor has a predict() method that takes a dataset of new instances and returns a dataset of corresponding predictions. It also has a score() method that measures the quality of the predictions, given a test set (and the corresponding labels, in the case of supervised learning algorithms).
#
# ### ...
#
# Reference to the base classes for all estimators in scikit-learn can be found at: https://github.com/scikit-learn/scikit-learn/blob/9aaed4987/sklearn/base.py#L153

# %%
from generators import *
from feature_generation import FeatureGeneration
from clean_data import CleanData
from preprocess_data import PreprocessData

# %%
clean_pipeline = make_pipeline(
    CleanData()
)

# %%
clean_trades = clean_pipeline.fit_transform(trades)
clean_trades.head()
# Out:
# test
#                             Unnamed: 0.1 Exchange Symbol  Trade_Volume  \
# 2020-01-03 09:15:00.424794          9328        P   AAPL            90
# 2020-01-03 09:15:00.596884          9329        K   AAPL            52
# 2020-01-03 09:15:00.596884          9330        K   AAPL             2
# 2020-01-03 09:15:00.596884          9331        K   AAPL            10
# 2020-01-03 09:15:00.596884          9332        K   AAPL             2
#
#                             Trade_Price Sale_Condition Source_of_Trade  \
# 2020-01-03 09:15:00.424794       297.49           @FTI               N
# 2020-01-03 09:15:00.596884       297.40           @ TI               N
# 2020-01-03 09:15:00.596884       297.40           @ TI               N
# 2020-01-03 09:15:00.596884       297.40           @ TI               N
# 2020-01-03 09:15:00.596884       297.40           @ TI               N
#
#                             Trade_Stop_Stock_Indicator  \
# 2020-01-03 09:15:00.424794                         NaN
# 2020-01-03 09:15:00.596884                         NaN
# 2020-01-03 09:15:00.596884                         NaN
# 2020-01-03 09:15:00.596884                         NaN
# 2020-01-03 09:15:00.596884                         NaN
#
#                             Trade_Correction_Indicator  Sequence_Number  \
# 2020-01-03 09:15:00.424794                           0            27834
# 2020-01-03 09:15:00.596884                           0            27835
# 2020-01-03 09:15:00.596884                           0            27836
# 2020-01-03 09:15:00.596884                           0            27837
# 2020-01-03 09:15:00.596884                           0            27838
#
#                             Trade_Id Trade_Reporting_Facility  \
# 2020-01-03 09:15:00.424794      2698
# 2020-01-03 09:15:00.596884      1702
# 2020-01-03 09:15:00.596884      1703
# 2020-01-03 09:15:00.596884      1704
# 2020-01-03 09:15:00.596884      1705
#
#                                 Participant_Timestamp  \
# 2020-01-03 09:15:00.424794 2020-01-03 09:15:00.424794
# 2020-01-03 09:15:00.596884 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884 2020-01-03 09:15:00.596884
#
#                             Trade_Reporting_Facility_TRF_Timestamp  \
# 2020-01-03 09:15:00.424794                                     NaN
# 2020-01-03 09:15:00.596884                                     NaN
# 2020-01-03 09:15:00.596884                                     NaN
# 2020-01-03 09:15:00.596884                                     NaN
# 2020-01-03 09:15:00.596884                                     NaN
#
#                             Trade_Through_Exempt_Indicator
# 2020-01-03 09:15:00.424794                               1
# 2020-01-03 09:15:00.596884                               0
# 2020-01-03 09:15:00.596884                               0
# 2020-01-03 09:15:00.596884                               0
# 2020-01-03 09:15:00.596884                               0

# %%
clean_quotes = clean_pipeline.fit_transform(quotes)
clean_quotes.head()
# Out:
# test
#                             Unnamed: 0.1 Exchange Symbol  Bid_Price  Bid_Size  \
# 2020-01-03 09:15:00.126824         18992        P   AAPL     297.31       3.0
# 2020-01-03 09:15:00.596884         18993        K   AAPL     297.40       1.0
# 2020-01-03 09:15:00.596884         18994        K   AAPL     297.40       1.0
# 2020-01-03 09:15:00.596884         18995        K   AAPL     297.38       2.0
# 2020-01-03 09:15:01.147613         18996        Q   AAPL     297.41       1.0
#
#                             Offer_Price  Offer_Size Quote_Condition  \
# 2020-01-03 09:15:00.126824       297.50         2.0               R
# 2020-01-03 09:15:00.596884       297.65        10.0               R
# 2020-01-03 09:15:00.596884       297.65        10.0               R
# 2020-01-03 09:15:00.596884       297.65        10.0               R
# 2020-01-03 09:15:01.147613       297.76         1.0               R
#
#                             Sequence_Number  National_BBO_Indicator  \
# 2020-01-03 09:15:00.126824           255901                       2
# 2020-01-03 09:15:00.596884           255944                       0
# 2020-01-03 09:15:00.596884           255945                       0
# 2020-01-03 09:15:00.596884           255946                       0
# 2020-01-03 09:15:01.147613           255970                       2
#
#                             FINRA_BBO_Indicator  FINRA_ADF_MPID_Indicator  \
# 2020-01-03 09:15:00.126824                  NaN                       NaN
# 2020-01-03 09:15:00.596884                  NaN                       NaN
# 2020-01-03 09:15:00.596884                  NaN                       NaN
# 2020-01-03 09:15:00.596884                  NaN                       NaN
# 2020-01-03 09:15:01.147613                  NaN                       NaN
#
#                             Quote_Cancel_Correction Source_Of_Quote  \
# 2020-01-03 09:15:00.126824                      NaN               N
# 2020-01-03 09:15:00.596884                      NaN               N
# 2020-01-03 09:15:00.596884                      NaN               N
# 2020-01-03 09:15:00.596884                      NaN               N
# 2020-01-03 09:15:01.147613                      NaN               N
#
#                            Retail_Interest_Indicator  \
# 2020-01-03 09:15:00.126824                       NaN
# 2020-01-03 09:15:00.596884                       NaN
# 2020-01-03 09:15:00.596884                       NaN
# 2020-01-03 09:15:00.596884                       NaN
# 2020-01-03 09:15:01.147613                       NaN
#
#                             Short_Sale_Restriction_Indicator  \
# 2020-01-03 09:15:00.126824                                 0
# 2020-01-03 09:15:00.596884                                 0
# 2020-01-03 09:15:00.596884                                 0
# 2020-01-03 09:15:00.596884                                 0
# 2020-01-03 09:15:01.147613                                 0
#
#                             LULD_BBO_Indicator  \
# 2020-01-03 09:15:00.126824                 NaN
# 2020-01-03 09:15:00.596884                 NaN
# 2020-01-03 09:15:00.596884                 NaN
# 2020-01-03 09:15:00.596884                 NaN
# 2020-01-03 09:15:01.147613                 NaN
#
#                            SIP_Generated_Message_Identifier  \
# 2020-01-03 09:15:00.126824                              NaN
# 2020-01-03 09:15:00.596884                              NaN
# 2020-01-03 09:15:00.596884                              NaN
# 2020-01-03 09:15:00.596884                              NaN
# 2020-01-03 09:15:01.147613                              NaN
#
#                            NBBO_LULD_Indicator      Participant_Timestamp  \
# 2020-01-03 09:15:00.126824                 NaN 2020-01-03 09:15:00.126824
# 2020-01-03 09:15:00.596884                 NaN 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884                 NaN 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884                 NaN 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:01.147613                 NaN 2020-01-03 09:15:01.147613
#
#                             FINRA_ADF_Timestamp  \
# 2020-01-03 09:15:00.126824                  NaN
# 2020-01-03 09:15:00.596884                  NaN
# 2020-01-03 09:15:00.596884                  NaN
# 2020-01-03 09:15:00.596884                  NaN
# 2020-01-03 09:15:01.147613                  NaN
#
#                             FINRA_ADF_Market_Participant_Quote_Indicator  \
# 2020-01-03 09:15:00.126824                                           NaN
# 2020-01-03 09:15:00.596884                                           NaN
# 2020-01-03 09:15:00.596884                                           NaN
# 2020-01-03 09:15:00.596884                                           NaN
# 2020-01-03 09:15:01.147613                                           NaN
#
#                            Security_Status_Indicator
# 2020-01-03 09:15:00.126824
# 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:00.596884
# 2020-01-03 09:15:01.147613

# %% [markdown]
# ### 1.4 Reconstructing Events

# %%
clean_trades['Is_Quote'] = False
clean_quotes['Is_Quote'] = True
trade_features = ['Symbol', 'Trade_Volume', 'Trade_Price', 'Trade_Id', 'Trade_Reporting_Facility', 'Participant_Timestamp', 'Is_Quote']
quote_features = ['Symbol', 'Bid_Price', 'Bid_Size', 'Offer_Price', 'Offer_Size', 'Participant_Timestamp', 'Is_Quote']

# %%
all_events = clean_trades[trade_features].append(clean_quotes[quote_features], ignore_index=True)
all_events.index.name = "RID"
all_events = all_events.sort_values(by=['Participant_Timestamp', all_events.index.name])
all_events.head(10)
# Out:
#        Symbol  Trade_Volume  Trade_Price  Trade_Id Trade_Reporting_Facility  \
# RID
# 247201   AAPL           NaN          NaN       NaN                      NaN
# 0        AAPL          90.0       297.49    2698.0
# 1        AAPL          52.0       297.40    1702.0
# 2        AAPL           2.0       297.40    1703.0
# 3        AAPL          10.0       297.40    1704.0
# 4        AAPL           2.0       297.40    1705.0
# 5        AAPL          94.0       297.40    1706.0
# 247202   AAPL           NaN          NaN       NaN                      NaN
# 247203   AAPL           NaN          NaN       NaN                      NaN
# 247204   AAPL           NaN          NaN       NaN                      NaN
#
#             Participant_Timestamp  Is_Quote  Bid_Price  Bid_Size  Offer_Price  \
# RID
# 247201 2020-01-03 09:15:00.126824      True     297.31       3.0       297.50
# 0      2020-01-03 09:15:00.424794     False        NaN       NaN          NaN
# 1      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 2      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 3      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 4      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 5      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 247202 2020-01-03 09:15:00.596884      True     297.40       1.0       297.65
# 247203 2020-01-03 09:15:00.596884      True     297.40       1.0       297.65
# 247204 2020-01-03 09:15:00.596884      True     297.38       2.0       297.65
#
#         Offer_Size
# RID
# 247201         2.0
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 247202        10.0
# 247203        10.0
# 247204        10.0

# %% [markdown]
# ### 1.5 Preprocess Data
#
# All preprossing steps are implemented according to the papaer: The Participant Timestamp: Get The Most Out Of TAQ Data https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3984827
#
# Trade direction is assigned using the tick test, which can be refered from the paper: Inferring Trade Direction from Intraday Data by Charles M. C. Lee, Mark J. Ready https://www.jstor.org/stable/2328845
#
# #### *For labeling valid quotes using AND(&) operator:
#
# |Is_Quote|valid_quotes|Desired|
# |---|---|---|
# |False|False|False|
# |False|True|False|
# |True|False|False|
# |True|True|True|

# %%
preprocess_pipeline = make_pipeline(
    PreprocessData()
)

# %%
df_prepared = preprocess_pipeline.fit_transform(all_events)
df_prepared.head(20)
# Out:
#        Symbol  Trade_Volume  Trade_Price  Trade_Id Trade_Reporting_Facility  \
# RID
# 247201   AAPL           NaN          NaN       NaN                      NaN
# 0        AAPL          90.0       297.49    2698.0
# 1        AAPL          52.0       297.40    1702.0
# 2        AAPL           2.0       297.40    1703.0
# 3        AAPL          10.0       297.40    1704.0
# 4        AAPL           2.0       297.40    1705.0
# 5        AAPL          94.0       297.40    1706.0
# 247202   AAPL           NaN          NaN       NaN                      NaN
# 247203   AAPL           NaN          NaN       NaN                      NaN
# 247204   AAPL           NaN          NaN       NaN                      NaN
# 247205   AAPL           NaN          NaN       NaN                      NaN
# 6        AAPL           3.0       297.49    2699.0
# 7        AAPL           1.0       297.49    2700.0
# 247206   AAPL           NaN          NaN       NaN                      NaN
# 247207   AAPL           NaN          NaN       NaN                      NaN
# 247208   AAPL           NaN          NaN       NaN                      NaN
# 8        AAPL          50.0       297.45    1707.0
# 247209   AAPL           NaN          NaN       NaN                      NaN
# 247210   AAPL           NaN          NaN       NaN                      NaN
# 247211   AAPL           NaN          NaN       NaN                      NaN
#
#             Participant_Timestamp  Is_Quote  Bid_Price  Bid_Size  Offer_Price  \
# RID
# 247201 2020-01-03 09:15:00.126824      True     297.31       3.0       297.50
# 0      2020-01-03 09:15:00.424794     False        NaN       NaN          NaN
# 1      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 2      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 3      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 4      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 5      2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 247202 2020-01-03 09:15:00.596884      True     297.40       1.0       297.65
# 247203 2020-01-03 09:15:00.596884      True     297.40       1.0       297.65
# 247204 2020-01-03 09:15:00.596884      True     297.38       2.0       297.65
# 247205 2020-01-03 09:15:01.147613      True     297.41       1.0       297.76
# 6      2020-01-03 09:15:02.209573     False        NaN       NaN          NaN
# 7      2020-01-03 09:15:02.848019     False        NaN       NaN          NaN
# 247206 2020-01-03 09:15:03.159605      True     297.45       2.0       297.76
# 247207 2020-01-03 09:15:03.468411      True     297.41       4.0       297.65
# 247208 2020-01-03 09:15:03.533008      True     297.45       1.0       297.65
# 8      2020-01-03 09:15:03.555156     False        NaN       NaN          NaN
# 247209 2020-01-03 09:15:03.555156      True     297.41       4.0       297.65
# 247210 2020-01-03 09:15:03.702244      True     297.47       5.0       297.76
# 247211 2020-01-03 09:15:05.655102      True     297.41       4.0       297.65
#
#         Offer_Size  MOX  Valid_Quotes  Trade_Sign  Participant_Timestamp_f
# RID
# 247201         2.0    0          True         NaN             1.578043e+09
# 0              NaN    1         False         1.0             1.578043e+09
# 1              NaN    2         False        -1.0             1.578043e+09
# 2              NaN    2         False        -1.0             1.578043e+09
# 3              NaN    2         False        -1.0             1.578043e+09
# 4              NaN    2         False        -1.0             1.578043e+09
# 5              NaN    2         False        -1.0             1.578043e+09
# 247202        10.0    2         False         NaN             1.578043e+09
# 247203        10.0    2         False         NaN             1.578043e+09
# 247204        10.0    2          True         NaN             1.578043e+09
# 247205         1.0    3          True         NaN             1.578043e+09
# 6              NaN    4         False         1.0             1.578043e+09
# 7              NaN    5         False         1.0             1.578043e+09
# 247206         1.0    6          True         NaN             1.578043e+09
# 247207        10.0    7          True         NaN             1.578043e+09
# 247208        10.0    8          True         NaN             1.578043e+09
# 8              NaN    9         False        -1.0             1.578043e+09
# 247209        10.0    9          True         NaN             1.578043e+09
# 247210         1.0   10          True         NaN             1.578043e+09
# 247211        10.0   11          True         NaN             1.578043e+09

# %%
df_prepared[df_prepared['MOX'] == 11]
# Out:
#        Symbol  Trade_Volume  Trade_Price  Trade_Id Trade_Reporting_Facility  \
# RID
# 247211   AAPL           NaN          NaN       NaN                      NaN
#
#             Participant_Timestamp  Is_Quote  Bid_Price  Bid_Size  Offer_Price  \
# RID
# 247211 2020-01-03 09:15:05.655102      True     297.41       4.0       297.65
#
#         Offer_Size  MOX  Valid_Quotes  Trade_Sign  Participant_Timestamp_f
# RID
# 247211        10.0   11          True         NaN             1.578043e+09

# %%
# import the set_config module from sklearn
from sklearn import set_config

# set the display option for sklearn to 'diagram'
set_config(display='diagram')

# display the pipeline 
preprocess_pipeline
# Out:
# Pipeline(steps=[('preprocessdata', PreprocessData())])

# %% [markdown]
# ## 2. Feature Generating Pipeline

# %% [markdown]
# ## 2.1 Generating Features

# %% [markdown]
# #### 2.1.1

# %% [markdown]
# #### 2.1.2 Return and Imbalance

# %% [markdown]
# #### 2.1.3

# %% [markdown]
# ## 2.2 Pipeline

# %% [markdown]
# ### 2.2.2 Feature Generation Pipeline

# %%
# df_test = df_prepared.copy()[:40000]
# df_test['Trade_Volume'] = df_test['Trade_Volume'].apply(lambda t: t if not np.isnan(t) else 0)
# df_test.reset_index(drop=True, inplace=True)
# df_test.head()
# Out:
#   Symbol  Trade_Volume  Trade_Price  Trade_Id Trade_Reporting_Facility  \
# 0   AAPL           0.0          NaN       NaN                      NaN
# 1   AAPL          90.0       297.49    2698.0
# 2   AAPL          52.0       297.40    1702.0
# 3   AAPL           2.0       297.40    1703.0
# 4   AAPL          10.0       297.40    1704.0
#
#        Participant_Timestamp  Is_Quote  Bid_Price  Bid_Size  Offer_Price  \
# 0 2020-01-03 09:15:00.126824      True     297.31       3.0        297.5
# 1 2020-01-03 09:15:00.424794     False        NaN       NaN          NaN
# 2 2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 3 2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
# 4 2020-01-03 09:15:00.596884     False        NaN       NaN          NaN
#
#    Offer_Size  MOX  Valid_Quotes  Trade_Sign  Participant_Timestamp_f
# 0         2.0    0          True         NaN             1.578043e+09
# 1         NaN    1         False         1.0             1.578043e+09
# 2         NaN    2         False        -1.0             1.578043e+09
# 3         NaN    2         False        -1.0             1.578043e+09
# 4         NaN    2         False        -1.0             1.578043e+09

# %%
# RETURN_CALENDAR_SPAN = 5
# RETURN_TRANSACTION_SPAN = None
# RETURN_VOLUME_SPAN = None

# CALENDAR_DELTAS = [(0,.1),(.1,.2),(.2,.4),(.4,.8),(.8,1.6),(1.6,3.2),(3.2,6.4),(6.4,12.8),(12.8,25.6)]
# TRANSACTION_DELTAS = [(0,1),(1,2),(2,4),(4,8),(8,16),(16,32),(32,64),(64,128),(128,256)]
# VOLUME_DELTAS = [(0,100),(100,200),(200,400),(400,800),(800,1600),(1600,3200),(3200,6400),(6400,12800),(12800,25600)]

# %%
# df_test = parent_generator_ret_imb(df_test, CALENDAR_DELTAS[:1])

# %%
# params = {
#     'return_span': RETURN_CALENDAR_SPAN,
#     'clock_mode': 'calendar',
#     'deltas': CALENDAR_DELTAS
# }

# %%
# feature_pipeline = make_pipeline(
#     FeatureGeneration()
# )
# df = feature_pipeline.fit_transform(df_test, params)
