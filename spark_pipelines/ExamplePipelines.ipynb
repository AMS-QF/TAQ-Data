# %% [markdown]
# # Example Pipelines Notebook
# (Not Actively Maintained - possible for bugs)

# %%
import warnings
import pandas as pd
from pathlib import Path
from sklearn.pipeline import make_pipeline

from generators import *
from clean_data import *
from preprocess_data import *
from feature_generation import *

warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Data
# ### 1.1 Load Sample Data

# %%
TRADES="../sample_data/trades.csv.gz"
QUOTES="../sample_data/quotes.csv.gz"

# %%
trades = pd.read_csv(Path(TRADES),compression='gzip')
quotes = pd.read_csv(Path(QUOTES),compression='gzip')

# %%
trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              1000 non-null   int64
#  1   Time                                    1000 non-null   object
#  2   Date                                    1000 non-null   object
#  3   Exchange                                1000 non-null   object
#  4   Symbol                                  1000 non-null   object
#  5   Trade_Volume                            1000 non-null   int64
#  6   Trade_Price                             1000 non-null   float64
#  7   Sale_Condition                          1000 non-null   object
#  8   Source_of_Trade                         1000 non-null   object
#  9   Trade_Stop_Stock_Indicator              0 non-null      float64
#  10  Trade_Correction_Indicator              1000 non-null   int64
#  11  Sequence_Number                         1000 non-null   int64
#  12  Trade_Id                                1000 non-null   int64
#  13  Trade_Reporting_Facility                1000 non-null   object
#  14  Participant_Timestamp                   1000 non-null   int64
#  15  Trade_Reporting_Facility_TRF_Timestamp  0 non-null      float64
#  16  Trade_Through_Exempt_Indicator          1000 non-null   int64
#  17  YearMonth                               1000 non-null   int64
# dtypes: float64(3), int64(8), object(7)
# memory usage: 140.8+ KB

# %% [markdown]
# Note: All column information of trades and quotes data and valid entries for each column can be found at https://www.nyse.com/publicdocs/nyse/data/Daily_TAQ_Client_Spec_v3.0.pdf

# %%
trades.head()
# Out:
#    Unnamed: 0                        Time        Date Exchange Symbol  \
# 0           0  2020-01-06 04:00:00.064682  2020-01-06        P   AAPL
# 1           1  2020-01-06 04:00:00.104067  2020-01-06        P   AAPL
# 2           2  2020-01-06 04:00:00.104069  2020-01-06        P   AAPL
# 3           3  2020-01-06 04:00:00.197526  2020-01-06        P   AAPL
# 4           4  2020-01-06 04:00:00.197530  2020-01-06        P   AAPL
#
#    Trade_Volume  Trade_Price Sale_Condition Source_of_Trade  \
# 0           488       295.43           @ T                N
# 1           100       295.26           @FT                N
# 2           100       295.25           @FT                N
# 3            25       295.12           @FTI               N
# 4             1       295.08           @FTI               N
#
#    Trade_Stop_Stock_Indicator  Trade_Correction_Indicator  Sequence_Number  \
# 0                         NaN                           0             1192
# 1                         NaN                           0             1195
# 2                         NaN                           0             1196
# 3                         NaN                           0             1198
# 4                         NaN                           0             1199
#
#    Trade_Id Trade_Reporting_Facility  Participant_Timestamp  \
# 0         1                                  40000064303360
# 1         2                                  40000103686400
# 2         3                                  40000103686400
# 3         4                                  40000197144064
# 4         5                                  40000197144064
#
#    Trade_Reporting_Facility_TRF_Timestamp  Trade_Through_Exempt_Indicator  \
# 0                                     NaN                               1
# 1                                     NaN                               1
# 2                                     NaN                               1
# 3                                     NaN                               1
# 4                                     NaN                               1
#
#    YearMonth
# 0     202001
# 1     202001
# 2     202001
# 3     202001
# 4     202001

# %%
quotes.head()
# Out:
#    Unnamed: 0                        Time Exchange Symbol  Bid_Price  \
# 0           0  2020-01-06 04:00:00.065815        P   AAPL     278.00
# 1           1  2020-01-06 04:00:00.065819        P   AAPL     278.00
# 2           2  2020-01-06 04:00:00.065822        P   AAPL     278.00
# 3           3  2020-01-06 04:00:00.065919        P   AAPL     291.20
# 4           4  2020-01-06 04:00:00.065966        P   AAPL     295.26
#
#    Bid_Size  Offer_Price  Offer_Size Quote_Condition  Sequence_Number  \
# 0       7.0         0.00         0.0               R             2251
# 1      14.0         0.00         0.0               R             2252
# 2      14.0       298.28         1.0               R             2253
# 3       1.0       298.28         1.0               R             2254
# 4       1.0       298.28         1.0               R             2255
#
#    National_BBO_Indicator  FINRA_BBO_Indicator  FINRA_ADF_MPID_Indicator  \
# 0                       2                  NaN                       NaN
# 1                       2                  NaN                       NaN
# 2                       4                  NaN                       NaN
# 3                       4                  NaN                       NaN
# 4                       4                  NaN                       NaN
#
#    Quote_Cancel_Correction Source_Of_Quote  Retail_Interest_Indicator  \
# 0                      NaN               N                        NaN
# 1                      NaN               N                        NaN
# 2                      NaN               N                        NaN
# 3                      NaN               N                        NaN
# 4                      NaN               N                        NaN
#
#    Short_Sale_Restriction_Indicator  LULD_BBO_Indicator  \
# 0                                 0                 NaN
# 1                                 0                 NaN
# 2                                 0                 NaN
# 3                                 0                 NaN
# 4                                 0                 NaN
#
#    SIP_Generated_Message_Identifier  NBBO_LULD_Indicator  \
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
#
#    Participant_Timestamp  FINRA_ADF_Timestamp  \
# 0         40000065434368                  NaN
# 1         40000065436672                  NaN
# 2         40000065441792                  NaN
# 3         40000065541888                  NaN
# 4         40000065584896                  NaN
#
#    FINRA_ADF_Market_Participant_Quote_Indicator Security_Status_Indicator  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#          Date  YearMonth
# 0  2020-01-06     202001
# 1  2020-01-06     202001
# 2  2020-01-06     202001
# 3  2020-01-06     202001
# 4  2020-01-06     202001

# %% [markdown]
# ### 1.2 Data Visualization & Preliminary Analysis

# %% [markdown]
# ### 1.3 Data Cleaning

# %% [markdown]
# Before we move towards feature generation and building machine learning models, we have to clean the dataset. The necessary steps to clean the trades and quotes data include:
# 1. Get rid of unnecessary columns.
# 2. Get rid of the invalid trades and quotes.
# 3. Event reconstruction.
# 4. Only keep the natural best bid/offer or last MQU.
# 5. Assign Last Active Quote and assign to the corresponding trade.

# %% [markdown]
# ## SCIKIT-LEARN DESIGN
#
# https://arxiv.org/pdf/1309.0238.pdf
#
# Scikit-Learn’s API is remarkably well designed. These are the main design components of Scikit-Learn.
#
# All objects share a consistent and simple interface:
#
# ### Estimators
#
# Any object that can estimate some parameters based on a dataset is called an estimator (e.g., a SimpleImputer is an estimator). The estimation itself is performed by the fit() method, and it takes a dataset as a parameter, or two for supervised learning algorithms—the second dataset contains the labels. Any other parameter needed to guide the estimation process is considered a hyperparameter (such as a SimpleImputer’s strategy), and it must be set as an instance variable (generally via a constructor parameter).
#
# ### Transformers
#
# Some estimators (such as a SimpleImputer) can also transform a dataset; these are called transformers. Once again, the API is simple: the transformation is performed by the transform() method with the dataset to transform as a parameter. It returns the transformed dataset. This transformation generally relies on the learned parameters, as is the case for a SimpleImputer. All transformers also have a convenience method called fit_transform(), which is equivalent to calling fit() and then transform() (but sometimes fit_transform() is optimized and runs much faster).
#
#
# ### Predictors
#
# Finally, some estimators, given a dataset, are capable of making predictions; they are called predictors. For example, the LinearRegression model in the previous chapter was a predictor: given a country’s GDP per capita, it predicted life satisfaction. A predictor has a predict() method that takes a dataset of new instances and returns a dataset of corresponding predictions. It also has a score() method that measures the quality of the predictions, given a test set (and the corresponding labels, in the case of supervised learning algorithms).
#
# ### ...
#
# Reference to the base classes for all estimators in scikit-learn can be found at: https://github.com/scikit-learn/scikit-learn/blob/9aaed4987/sklearn/base.py#L153

# %%
clean_pipeline = make_pipeline(
    CleanData(dropped_after_hourse=False,droped_irregular_hours=False)
)

# %%
clean_trades = clean_pipeline.fit_transform(trades)
clean_trades
# Out:
# test
#                            Exchange Symbol  Trade_Volume  Trade_Price  \
# 2020-01-06 04:00:00.064303        P   AAPL           488       295.43
# 2020-01-06 04:00:00.103686        P   AAPL           100       295.26
# 2020-01-06 04:00:00.103686        P   AAPL           100       295.25
# 2020-01-06 04:00:00.197144        P   AAPL            25       295.12
# 2020-01-06 04:00:00.197144        P   AAPL             1       295.08
# ...                             ...    ...           ...          ...
# 2020-01-06 06:45:16.264262        Q   AAPL           188       294.52
# 2020-01-06 06:45:16.264262        Q   AAPL           113       294.51
# 2020-01-06 06:45:18.768598        Q   AAPL           387       294.51
# 2020-01-06 06:45:18.769039        P   AAPL           100       294.50
# 2020-01-06 06:45:18.769479        Q   AAPL            13       294.50
#
#                            Sale_Condition Source_of_Trade  \
# 2020-01-06 04:00:00.064303           @ T                N
# 2020-01-06 04:00:00.103686           @FT                N
# 2020-01-06 04:00:00.103686           @FT                N
# 2020-01-06 04:00:00.197144           @FTI               N
# 2020-01-06 04:00:00.197144           @FTI               N
# ...                                   ...             ...
# 2020-01-06 06:45:16.264262           @FT                N
# 2020-01-06 06:45:16.264262           @FT                N
# 2020-01-06 06:45:18.768598           @FT                N
# 2020-01-06 06:45:18.769039           @FT                N
# 2020-01-06 06:45:18.769479           @FTI               N
#
#                             Trade_Stop_Stock_Indicator  \
# 2020-01-06 04:00:00.064303                         NaN
# 2020-01-06 04:00:00.103686                         NaN
# 2020-01-06 04:00:00.103686                         NaN
# 2020-01-06 04:00:00.197144                         NaN
# 2020-01-06 04:00:00.197144                         NaN
# ...                                                ...
# 2020-01-06 06:45:16.264262                         NaN
# 2020-01-06 06:45:16.264262                         NaN
# 2020-01-06 06:45:18.768598                         NaN
# 2020-01-06 06:45:18.769039                         NaN
# 2020-01-06 06:45:18.769479                         NaN
#
#                             Trade_Correction_Indicator  Sequence_Number  \
# 2020-01-06 04:00:00.064303                           0             1192
# 2020-01-06 04:00:00.103686                           0             1195
# 2020-01-06 04:00:00.103686                           0             1196
# 2020-01-06 04:00:00.197144                           0             1198
# 2020-01-06 04:00:00.197144                           0             1199
# ...                                                ...              ...
# 2020-01-06 06:45:16.264262                           0             3394
# 2020-01-06 06:45:16.264262                           0             3395
# 2020-01-06 06:45:18.768598                           0             3396
# 2020-01-06 06:45:18.769039                           0             3397
# 2020-01-06 06:45:18.769479                           0             3398
#
#                             Trade_Id Trade_Reporting_Facility  \
# 2020-01-06 04:00:00.064303         1
# 2020-01-06 04:00:00.103686         2
# 2020-01-06 04:00:00.103686         3
# 2020-01-06 04:00:00.197144         4
# 2020-01-06 04:00:00.197144         5
# ...                              ...                      ...
# 2020-01-06 06:45:16.264262       612
# 2020-01-06 06:45:16.264262       613
# 2020-01-06 06:45:18.768598       614
# 2020-01-06 06:45:18.769039       385
# 2020-01-06 06:45:18.769479       615
#
#                                 Participant_Timestamp  \
# 2020-01-06 04:00:00.064303 2020-01-06 04:00:00.064303
# 2020-01-06 04:00:00.103686 2020-01-06 04:00:00.103686
# 2020-01-06 04:00:00.103686 2020-01-06 04:00:00.103686
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144
# ...                                               ...
# 2020-01-06 06:45:16.264262 2020-01-06 06:45:16.264262
# 2020-01-06 06:45:16.264262 2020-01-06 06:45:16.264262
# 2020-01-06 06:45:18.768598 2020-01-06 06:45:18.768598
# 2020-01-06 06:45:18.769039 2020-01-06 06:45:18.769039
# 2020-01-06 06:45:18.769479 2020-01-06 06:45:18.769479
#
#                             Trade_Reporting_Facility_TRF_Timestamp  \
# 2020-01-06 04:00:00.064303                                     NaN
# 2020-01-06 04:00:00.103686                                     NaN
# 2020-01-06 04:00:00.103686                                     NaN
# 2020-01-06 04:00:00.197144                                     NaN
# 2020-01-06 04:00:00.197144                                     NaN
# ...                                                            ...
# 2020-01-06 06:45:16.264262                                     NaN
# 2020-01-06 06:45:16.264262                                     NaN
# 2020-01-06 06:45:18.768598                                     NaN
# 2020-01-06 06:45:18.769039                                     NaN
# 2020-01-06 06:45:18.769479                                     NaN
#
#                             Trade_Through_Exempt_Indicator
# 2020-01-06 04:00:00.064303                               1
# 2020-01-06 04:00:00.103686                               1
# 2020-01-06 04:00:00.103686                               1
# 2020-01-06 04:00:00.197144                               1
# 2020-01-06 04:00:00.197144                               1
# ...                                                    ...
# 2020-01-06 06:45:16.264262                               1
# 2020-01-06 06:45:16.264262                               1
# 2020-01-06 06:45:18.768598                               1
# 2020-01-06 06:45:18.769039                               1
# 2020-01-06 06:45:18.769479                               1
#
# [1000 rows x 14 columns]

# %%
clean_quotes = clean_pipeline.fit_transform(quotes)
clean_quotes.head()
# Out:
# test
#                            Exchange Symbol  Bid_Price  Bid_Size  Offer_Price  \
# 2020-01-06 04:00:00.065434        P   AAPL     278.00       7.0         0.00
# 2020-01-06 04:00:00.065436        P   AAPL     278.00      14.0         0.00
# 2020-01-06 04:00:00.065441        P   AAPL     278.00      14.0       298.28
# 2020-01-06 04:00:00.065541        P   AAPL     291.20       1.0       298.28
# 2020-01-06 04:00:00.065584        P   AAPL     295.26       1.0       298.28
#
#                             Offer_Size Quote_Condition  Sequence_Number  \
# 2020-01-06 04:00:00.065434         0.0               R             2251
# 2020-01-06 04:00:00.065436         0.0               R             2252
# 2020-01-06 04:00:00.065441         1.0               R             2253
# 2020-01-06 04:00:00.065541         1.0               R             2254
# 2020-01-06 04:00:00.065584         1.0               R             2255
#
#                             National_BBO_Indicator  FINRA_BBO_Indicator  \
# 2020-01-06 04:00:00.065434                       2                  NaN
# 2020-01-06 04:00:00.065436                       2                  NaN
# 2020-01-06 04:00:00.065441                       4                  NaN
# 2020-01-06 04:00:00.065541                       4                  NaN
# 2020-01-06 04:00:00.065584                       4                  NaN
#
#                             FINRA_ADF_MPID_Indicator  Quote_Cancel_Correction  \
# 2020-01-06 04:00:00.065434                       NaN                      NaN
# 2020-01-06 04:00:00.065436                       NaN                      NaN
# 2020-01-06 04:00:00.065441                       NaN                      NaN
# 2020-01-06 04:00:00.065541                       NaN                      NaN
# 2020-01-06 04:00:00.065584                       NaN                      NaN
#
#                            Source_Of_Quote  Retail_Interest_Indicator  \
# 2020-01-06 04:00:00.065434               N                        NaN
# 2020-01-06 04:00:00.065436               N                        NaN
# 2020-01-06 04:00:00.065441               N                        NaN
# 2020-01-06 04:00:00.065541               N                        NaN
# 2020-01-06 04:00:00.065584               N                        NaN
#
#                             Short_Sale_Restriction_Indicator  \
# 2020-01-06 04:00:00.065434                                 0
# 2020-01-06 04:00:00.065436                                 0
# 2020-01-06 04:00:00.065441                                 0
# 2020-01-06 04:00:00.065541                                 0
# 2020-01-06 04:00:00.065584                                 0
#
#                             LULD_BBO_Indicator  \
# 2020-01-06 04:00:00.065434                 NaN
# 2020-01-06 04:00:00.065436                 NaN
# 2020-01-06 04:00:00.065441                 NaN
# 2020-01-06 04:00:00.065541                 NaN
# 2020-01-06 04:00:00.065584                 NaN
#
#                             SIP_Generated_Message_Identifier  \
# 2020-01-06 04:00:00.065434                               NaN
# 2020-01-06 04:00:00.065436                               NaN
# 2020-01-06 04:00:00.065441                               NaN
# 2020-01-06 04:00:00.065541                               NaN
# 2020-01-06 04:00:00.065584                               NaN
#
#                             NBBO_LULD_Indicator      Participant_Timestamp  \
# 2020-01-06 04:00:00.065434                  NaN 2020-01-06 04:00:00.065434
# 2020-01-06 04:00:00.065436                  NaN 2020-01-06 04:00:00.065436
# 2020-01-06 04:00:00.065441                  NaN 2020-01-06 04:00:00.065441
# 2020-01-06 04:00:00.065541                  NaN 2020-01-06 04:00:00.065541
# 2020-01-06 04:00:00.065584                  NaN 2020-01-06 04:00:00.065584
#
#                             FINRA_ADF_Timestamp  \
# 2020-01-06 04:00:00.065434                  NaN
# 2020-01-06 04:00:00.065436                  NaN
# 2020-01-06 04:00:00.065441                  NaN
# 2020-01-06 04:00:00.065541                  NaN
# 2020-01-06 04:00:00.065584                  NaN
#
#                             FINRA_ADF_Market_Participant_Quote_Indicator  \
# 2020-01-06 04:00:00.065434                                           NaN
# 2020-01-06 04:00:00.065436                                           NaN
# 2020-01-06 04:00:00.065441                                           NaN
# 2020-01-06 04:00:00.065541                                           NaN
# 2020-01-06 04:00:00.065584                                           NaN
#
#                            Security_Status_Indicator
# 2020-01-06 04:00:00.065434
# 2020-01-06 04:00:00.065436
# 2020-01-06 04:00:00.065441
# 2020-01-06 04:00:00.065541
# 2020-01-06 04:00:00.065584

# %% [markdown]
# ### 1.4 Reconstructing Events

# %%
clean_trades['Is_Quote'] = False
clean_quotes['Is_Quote'] = True
trade_features = ['Symbol', 'Trade_Volume', 'Trade_Price', 'Trade_Id', 'Trade_Reporting_Facility', 'Participant_Timestamp', 'Is_Quote']
quote_features = ['Symbol', 'Bid_Price', 'Bid_Size', 'Offer_Price', 'Offer_Size', 'Participant_Timestamp', 'Is_Quote']

# %%
all_events = pd.concat([clean_trades[trade_features],clean_quotes[quote_features]])
all_events.index.name = "RID"
all_events = all_events.sort_values(by=['Participant_Timestamp', all_events.index.name])
all_events.head(10)
# Out:
#                            Symbol  Trade_Volume  Trade_Price  Trade_Id  \
# RID
# 2020-01-06 04:00:00.064303   AAPL         488.0       295.43       1.0
# 2020-01-06 04:00:00.065434   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065436   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065441   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065541   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065584   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065954   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.066140   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.067948   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.068447   AAPL           NaN          NaN       NaN
#
#                            Trade_Reporting_Facility  \
# RID
# 2020-01-06 04:00:00.064303
# 2020-01-06 04:00:00.065434                      NaN
# 2020-01-06 04:00:00.065436                      NaN
# 2020-01-06 04:00:00.065441                      NaN
# 2020-01-06 04:00:00.065541                      NaN
# 2020-01-06 04:00:00.065584                      NaN
# 2020-01-06 04:00:00.065954                      NaN
# 2020-01-06 04:00:00.066140                      NaN
# 2020-01-06 04:00:00.067948                      NaN
# 2020-01-06 04:00:00.068447                      NaN
#
#                                 Participant_Timestamp  Is_Quote  Bid_Price  \
# RID
# 2020-01-06 04:00:00.064303 2020-01-06 04:00:00.064303     False        NaN
# 2020-01-06 04:00:00.065434 2020-01-06 04:00:00.065434      True     278.00
# 2020-01-06 04:00:00.065436 2020-01-06 04:00:00.065436      True     278.00
# 2020-01-06 04:00:00.065441 2020-01-06 04:00:00.065441      True     278.00
# 2020-01-06 04:00:00.065541 2020-01-06 04:00:00.065541      True     291.20
# 2020-01-06 04:00:00.065584 2020-01-06 04:00:00.065584      True     295.26
# 2020-01-06 04:00:00.065954 2020-01-06 04:00:00.065954      True     295.26
# 2020-01-06 04:00:00.066140 2020-01-06 04:00:00.066140      True     295.26
# 2020-01-06 04:00:00.067948 2020-01-06 04:00:00.067948      True     295.26
# 2020-01-06 04:00:00.068447 2020-01-06 04:00:00.068447      True     295.26
#
#                             Bid_Size  Offer_Price  Offer_Size
# RID
# 2020-01-06 04:00:00.064303       NaN          NaN         NaN
# 2020-01-06 04:00:00.065434       7.0         0.00         0.0
# 2020-01-06 04:00:00.065436      14.0         0.00         0.0
# 2020-01-06 04:00:00.065441      14.0       298.28         1.0
# 2020-01-06 04:00:00.065541       1.0       298.28         1.0
# 2020-01-06 04:00:00.065584       1.0       298.28         1.0
# 2020-01-06 04:00:00.065954       1.0       298.00         1.0
# 2020-01-06 04:00:00.066140       1.0       297.49         1.0
# 2020-01-06 04:00:00.067948       1.0       297.13         1.0
# 2020-01-06 04:00:00.068447       1.0       296.98         1.0

# %% [markdown]
# ### 1.5 Preprocess Data
#
# All preprossing steps are implemented according to the papaer: The Participant Timestamp: Get The Most Out Of TAQ Data https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3984827
#
# Trade direction is assigned using the tick test, which can be refered from the paper: Inferring Trade Direction from Intraday Data by Charles M. C. Lee, Mark J. Ready https://www.jstor.org/stable/2328845
#
# #### *For labeling valid quotes using AND(&) operator:
#
# |Is_Quote|valid_quotes|Desired|
# |---|---|---|
# |False|False|False|
# |False|True|False|
# |True|False|False|
# |True|True|True|

# %%
preprocess_pipeline = make_pipeline(
    PreprocessData()
)

# %%
df_prepared = preprocess_pipeline.fit_transform(all_events)
df_prepared.head(20)
# Out:
#                            Symbol  Trade_Volume  Trade_Price  Trade_Id  \
# RID
# 2020-01-06 04:00:00.064303   AAPL         488.0       295.43       1.0
# 2020-01-06 04:00:00.065441   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065541   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065584   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.065954   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.066140   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.067948   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.068447   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.068493   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.068493   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.068545   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.103686   AAPL         100.0       295.26       2.0
# 2020-01-06 04:00:00.103686   AAPL         100.0       295.25       3.0
# 2020-01-06 04:00:00.103686   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.197144   AAPL          25.0       295.12       4.0
# 2020-01-06 04:00:00.197144   AAPL           1.0       295.08       5.0
# 2020-01-06 04:00:00.197144   AAPL          20.0       295.00       6.0
# 2020-01-06 04:00:00.197144   AAPL           NaN          NaN       NaN
# 2020-01-06 04:00:00.197318   AAPL           1.0       295.00       7.0
# 2020-01-06 04:00:00.265844   AAPL          79.0       295.00       8.0
#
#                            Trade_Reporting_Facility  \
# RID
# 2020-01-06 04:00:00.064303
# 2020-01-06 04:00:00.065441                      NaN
# 2020-01-06 04:00:00.065541                      NaN
# 2020-01-06 04:00:00.065584                      NaN
# 2020-01-06 04:00:00.065954                      NaN
# 2020-01-06 04:00:00.066140                      NaN
# 2020-01-06 04:00:00.067948                      NaN
# 2020-01-06 04:00:00.068447                      NaN
# 2020-01-06 04:00:00.068493                      NaN
# 2020-01-06 04:00:00.068493                      NaN
# 2020-01-06 04:00:00.068545                      NaN
# 2020-01-06 04:00:00.103686
# 2020-01-06 04:00:00.103686
# 2020-01-06 04:00:00.103686                      NaN
# 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144                      NaN
# 2020-01-06 04:00:00.197318
# 2020-01-06 04:00:00.265844
#
#                                 Participant_Timestamp  Is_Quote  Bid_Price  \
# RID
# 2020-01-06 04:00:00.064303 2020-01-06 04:00:00.064303     False        NaN
# 2020-01-06 04:00:00.065441 2020-01-06 04:00:00.065441      True     278.00
# 2020-01-06 04:00:00.065541 2020-01-06 04:00:00.065541      True     291.20
# 2020-01-06 04:00:00.065584 2020-01-06 04:00:00.065584      True     295.26
# 2020-01-06 04:00:00.065954 2020-01-06 04:00:00.065954      True     295.26
# 2020-01-06 04:00:00.066140 2020-01-06 04:00:00.066140      True     295.26
# 2020-01-06 04:00:00.067948 2020-01-06 04:00:00.067948      True     295.26
# 2020-01-06 04:00:00.068447 2020-01-06 04:00:00.068447      True     295.26
# 2020-01-06 04:00:00.068493 2020-01-06 04:00:00.068493      True     295.26
# 2020-01-06 04:00:00.068493 2020-01-06 04:00:00.068493      True     295.26
# 2020-01-06 04:00:00.068545 2020-01-06 04:00:00.068545      True     295.26
# 2020-01-06 04:00:00.103686 2020-01-06 04:00:00.103686     False        NaN
# 2020-01-06 04:00:00.103686 2020-01-06 04:00:00.103686     False        NaN
# 2020-01-06 04:00:00.103686 2020-01-06 04:00:00.103686      True     295.00
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144     False        NaN
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144     False        NaN
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144     False        NaN
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144      True     295.00
# 2020-01-06 04:00:00.197318 2020-01-06 04:00:00.197318     False        NaN
# 2020-01-06 04:00:00.265844 2020-01-06 04:00:00.265844     False        NaN
#
#                             Bid_Size  Offer_Price  Offer_Size  MOX  \
# RID
# 2020-01-06 04:00:00.064303       NaN          NaN         NaN    0
# 2020-01-06 04:00:00.065441      14.0       298.28         1.0    1
# 2020-01-06 04:00:00.065541       1.0       298.28         1.0    2
# 2020-01-06 04:00:00.065584       1.0       298.28         1.0    3
# 2020-01-06 04:00:00.065954       1.0       298.00         1.0    4
# 2020-01-06 04:00:00.066140       1.0       297.49         1.0    5
# 2020-01-06 04:00:00.067948       1.0       297.13         1.0    6
# 2020-01-06 04:00:00.068447       1.0       296.98         1.0    7
# 2020-01-06 04:00:00.068493       1.0       296.98        11.0    8
# 2020-01-06 04:00:00.068493       1.0       296.00         6.0    8
# 2020-01-06 04:00:00.068545       1.0       295.55         1.0    9
# 2020-01-06 04:00:00.103686       NaN          NaN         NaN   10
# 2020-01-06 04:00:00.103686       NaN          NaN         NaN   10
# 2020-01-06 04:00:00.103686       2.0       295.55         1.0   10
# 2020-01-06 04:00:00.197144       NaN          NaN         NaN   11
# 2020-01-06 04:00:00.197144       NaN          NaN         NaN   11
# 2020-01-06 04:00:00.197144       NaN          NaN         NaN   11
# 2020-01-06 04:00:00.197144       1.0       295.55         1.0   11
# 2020-01-06 04:00:00.197318       NaN          NaN         NaN   12
# 2020-01-06 04:00:00.265844       NaN          NaN         NaN   13
#
#                             Valid_Quotes  Trade_Sign  Participant_Timestamp_f
# RID
# 2020-01-06 04:00:00.064303         False         1.0             1.578283e+09
# 2020-01-06 04:00:00.065441          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.065541          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.065584          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.065954          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.066140          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.067948          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.068447          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.068493         False         NaN             1.578283e+09
# 2020-01-06 04:00:00.068493          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.068545          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.103686         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.103686         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.103686          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.197144         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.197144         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.197144         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.197144          True         NaN             1.578283e+09
# 2020-01-06 04:00:00.197318         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.265844         False        -1.0             1.578283e+09

# %%
df_prepared[df_prepared['MOX'] == 11]
# Out:
#                            Symbol  Trade_Volume  Trade_Price  Trade_Id  \
# RID
# 2020-01-06 04:00:00.197144   AAPL          25.0       295.12       4.0
# 2020-01-06 04:00:00.197144   AAPL           1.0       295.08       5.0
# 2020-01-06 04:00:00.197144   AAPL          20.0       295.00       6.0
# 2020-01-06 04:00:00.197144   AAPL           NaN          NaN       NaN
#
#                            Trade_Reporting_Facility  \
# RID
# 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144
# 2020-01-06 04:00:00.197144                      NaN
#
#                                 Participant_Timestamp  Is_Quote  Bid_Price  \
# RID
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144     False        NaN
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144     False        NaN
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144     False        NaN
# 2020-01-06 04:00:00.197144 2020-01-06 04:00:00.197144      True      295.0
#
#                             Bid_Size  Offer_Price  Offer_Size  MOX  \
# RID
# 2020-01-06 04:00:00.197144       NaN          NaN         NaN   11
# 2020-01-06 04:00:00.197144       NaN          NaN         NaN   11
# 2020-01-06 04:00:00.197144       NaN          NaN         NaN   11
# 2020-01-06 04:00:00.197144       1.0       295.55         1.0   11
#
#                             Valid_Quotes  Trade_Sign  Participant_Timestamp_f
# RID
# 2020-01-06 04:00:00.197144         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.197144         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.197144         False        -1.0             1.578283e+09
# 2020-01-06 04:00:00.197144          True         NaN             1.578283e+09

# %%
# import the set_config module from sklearn
from sklearn import set_config

# set the display option for sklearn to 'diagram'
set_config(display='diagram')

# display the pipeline 
preprocess_pipeline
# Out:
# Pipeline(steps=[('preprocessdata', PreprocessData())])

# %% [markdown]
# ## 2. Feature Generating Pipeline

# %% [markdown]
# ## 2.1 Generating Features

# %% [markdown]
# #### 2.1.1

# %% [markdown]
# #### 2.1.2 Return and Imbalance

# %% [markdown]
# #### 2.1.3

# %% [markdown]
# ## 2.2 Pipeline

# %% [markdown]
# ### 2.2.2 Feature Generation Pipeline

# %%
df_test = df_prepared.copy()[:40000]
df_test['Trade_Volume'] = df_test['Trade_Volume'].apply(lambda t: t if not np.isnan(t) else 0)
df_test.reset_index(drop=True, inplace=True)
df_test.head()
# Out:
#   Symbol  Trade_Volume  Trade_Price  Trade_Id Trade_Reporting_Facility  \
# 0   AAPL         488.0       295.43       1.0
# 1   AAPL           0.0          NaN       NaN                      NaN
# 2   AAPL           0.0          NaN       NaN                      NaN
# 3   AAPL           0.0          NaN       NaN                      NaN
# 4   AAPL           0.0          NaN       NaN                      NaN
#
#        Participant_Timestamp  Is_Quote  Bid_Price  Bid_Size  Offer_Price  \
# 0 2020-01-06 04:00:00.064303     False        NaN       NaN          NaN
# 1 2020-01-06 04:00:00.065441      True     278.00      14.0       298.28
# 2 2020-01-06 04:00:00.065541      True     291.20       1.0       298.28
# 3 2020-01-06 04:00:00.065584      True     295.26       1.0       298.28
# 4 2020-01-06 04:00:00.065954      True     295.26       1.0       298.00
#
#    Offer_Size  MOX  Valid_Quotes  Trade_Sign  Participant_Timestamp_f
# 0         NaN    0         False         1.0             1.578283e+09
# 1         1.0    1          True         NaN             1.578283e+09
# 2         1.0    2          True         NaN             1.578283e+09
# 3         1.0    3          True         NaN             1.578283e+09
# 4         1.0    4          True         NaN             1.578283e+09

# %%
RETURN_CALENDAR_SPAN = 5
RETURN_TRANSACTION_SPAN = None
RETURN_VOLUME_SPAN = None

CALENDAR_DELTAS = [(0,.1),(.1,.2),(.2,.4),(.4,.8),(.8,1.6),(1.6,3.2),(3.2,6.4),(6.4,12.8),(12.8,25.6)]
TRANSACTION_DELTAS = [(0,1),(1,2),(2,4),(4,8),(8,16),(16,32),(32,64),(64,128),(128,256)]
VOLUME_DELTAS = [(0,100),(100,200),(200,400),(400,800),(800,1600),(1600,3200),(3200,6400),(6400,12800),(12800,25600)]

# %%
# df_test = parent_generator_ret_imb(df_test, CALENDAR_DELTAS[:1])

# %%
params = {
    'return_span': RETURN_CALENDAR_SPAN,
    'clock_mode': 'calendar',
    'deltas': CALENDAR_DELTAS
}

# %%
feature_pipeline = make_pipeline(
    FeatureGeneration()
)
df = feature_pipeline.fit_transform(df_test, params)
